# %%
from bertopic import BERTopic

# %%
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(
    subset='all',
    remove=('headers', 'footers', 'quotes')
)['data']

# %%
import re

def clean_strings(strings):
    cleaned = []

    for s in strings:
        s = s.replace("\n", " ").replace("\t", " ")  # normalize whitespace chars
        s = re.sub(r"\s+", " ", s)                   # collapse multiple spaces
        s = s.strip()                                # trim ends
        cleaned.append(s)

    return cleaned

# %%
docs = clean_strings(docs)
print(docs[0])
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack of any kind of posts about the recent Pens massacre of the Devils. Actually, I am bit puzzled too and a bit relieved. However, I am going to put an end to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they are killing those Devils worse than I thought. Jagr just showed you why he is much better than his regular season stats. He is also a lot fo fun to watch in the playoffs. Bowman should let JAgr have a lot of fun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final regular season game. PENS RULE!!!

# %%
topic_model = BERTopic()

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info(topics[0])['Representation']
# Out:
#    Topic  Count                  Name         CustomName  \
# 0      0   1830  0_game_team_games_he  game, team, games
#
#                                       Representation  \
# 0  [game, team, games, he, players, season, hocke...
#
#                                  Representative_Docs
# 0  [No. Patrick Roy is the reason the game was lo...

# %%
topic_labels = topic_model.generate_topic_labels(
    nr_words=3,
    topic_prefix=False,
    word_length=15,
    separator=", "
)

topic_model.set_topic_labels(topic_labels)

# %%
freq = topic_model.get_topic_info()
print("Number of topics: {}".format( len(freq)))
freq.head()
# Out:
# Number of topics: 229
#    Topic  Count                           Name             CustomName  \
# 0     -1   6781               -1_to_the_and_of           to, the, and
# 1      0   1830           0_game_team_games_he      game, team, games
# 2      1    631  1_key_clipper_chip_encryption     key, clipper, chip
# 3      2    529          2_ites_hello_cheek_hi     ites, hello, cheek
# 4      3    324    3_israel_israeli_arab_arabs  israel, israeli, arab
#
#                                       Representation  \
# 0     [to, the, and, of, is, you, for, in, it, that]
# 1  [game, team, games, he, players, season, hocke...
# 2  [key, clipper, chip, encryption, keys, governm...
# 3  [ites, hello, cheek, hi, yep, huh, ken, forget...
# 4  [israel, israeli, arab, arabs, jews, palestini...
#
#                                  Representative_Docs
# 0  [Horrors, appealing to popular principles. Can...
# 1  [No. Patrick Roy is the reason the game was lo...
# ...

# %%
topic_model.get_topics()
# Out:
# {-1: [('to', np.float64(0.004196020427704575)),
#   ('the', np.float64(0.004103207022718623)),
#   ('and', np.float64(0.004055033082949918)),
#   ('of', np.float64(0.004047627581974989)),
#   ('is', np.float64(0.003944882076913633)),
#   ('you', np.float64(0.0039000771444144947)),
#   ('for', np.float64(0.003874628390415412)),
#   ('in', np.float64(0.0038488845278829183)),
#   ('it', np.float64(0.0037754977024464917)),
#   ('that', np.float64(0.003716207734056328))],
#  0: [('game', np.float64(0.010183015609151828)),
#   ('team', np.float64(0.008890573478321003)),
#   ('games', np.float64(0.007088290686189684)),
#   ('he', np.float64(0.006826941664884381)),
#   ('players', np.float64(0.0062401691860741165)),
#   ('season', np.float64(0.006172121876681058)),
#   ('hockey', np.float64(0.006038883331748317)),
#   ('play', np.float64(0.005692766142152251)),
#   ('25', np.float64(0.00555827016064377)),
#   ('year', np.float64(0.005511816032607346))],
# ...

# %%
# Select the 1st topic
a_topic = freq.iloc[1]["Topic"]
print(f'{a_topic=}')

# Show the words and their c-TF-IDF scores
topic_model.get_topic(a_topic)
# Out:
# a_topic=np.int64(0)
# [('game', np.float64(0.010183015609151828)),
#  ('team', np.float64(0.008890573478321003)),
#  ('games', np.float64(0.007088290686189684)),
#  ('he', np.float64(0.006826941664884381)),
#  ('players', np.float64(0.0062401691860741165)),
#  ('season', np.float64(0.006172121876681058)),
#  ('hockey', np.float64(0.006038883331748317)),
#  ('play', np.float64(0.005692766142152251)),
#  ('25', np.float64(0.00555827016064377)),
#  ('year', np.float64(0.005511816032607346))]

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_distribution(probs)

# %%
labels = topic_model.generate_topic_labels(
    nr_words=3,
    topic_prefix=False,
    word_length=15,
    separator=", "
)


label_mapping = dict(zip(topic_model.get_topics().keys(), labels))
label_mapping
# Out:
# {-1: 'to, the, and',
#  0: 'game, team, games',
#  1: 'key, clipper, chip',
#  2: 'ites, hello, cheek',
#  3: 'israel, israeli, arab',
#  4: 'post, ted, you',
#  5: 'space, launch, station',
#  6: 'amp, sound, audio',
#  7: 'card, drivers, diamond',
#  8: 'car, cars, mustang',
#  9: 'openwindows, motif, xfree86',
#  10: 'atheists, god, atheism',
#  11: 'printer, print, deskjet',
#  12: 'gun, guns, firearms',
#  13: 'window, widget, event',
#  14: 'drive, drives, disk',
#  15: 'bike, bikes, miles',
#  16: 'armenian, armenians, turkish',
#  17: 'moral, objective, morality',
#  18: 'den, polygon, points',
#  19: 'monitor, vga, monitors',
#  20: 'health, tobacco, cesarean',
#  21: 'migraine, drug, diet',
#  22: '3d, graphics, grafsys',
#  23: 'modem, port, serial',
#  24: 'jews, nazis, nazi',
#  25: 'lane, car, cop',
#  26: 'islam, quran, islamic',
#  27: 'simms, simm, vram',
#  28: 'serbs, muslims, stephanopoulos',
#  29: 'games, joystick, sega',
#  30: 'fire, fbi, bds',
# ...

# %%
similar_topics, similarity = topic_model.find_topics("religion", top_n = 3)

print(similar_topics)
print(similarity)
# Out:
# [142, 177, 10]
# [np.float32(0.46104175), np.float32(0.4203058), np.float32(0.40645438)]

# %%
most_similar = similar_topics[0]
print("Most Similar Topic Info:")
topic_model.get_topic(most_similar)
# Out:
# Most Similar Topic Info:
# [('silence', np.float64(0.03230652414894179)),
#  ('moment', np.float64(0.0321242444680759)),
#  ('schools', np.float64(0.030773040872067316)),
#  ('prayer', np.float64(0.024646652800495432)),
#  ('cult', np.float64(0.023568146268804043)),
#  ('religion', np.float64(0.020875009603932942)),
#  ('public', np.float64(0.018126451305906014)),
#  ('pray', np.float64(0.016547942211910204)),
#  ('christian', np.float64(0.014777593811166194)),
#  ('bibles', np.float64(0.014363813558540182))]

# %%
result = topic_model.get_document_info(docs)
result
# Out:
#                                                 Document  Topic  \
# 0      I am sure some bashers of Pens fans are pretty...      0
# 1      My brother is in the market for a high-perform...      7
# 2      Finally you said what you dream about. Mediter...     16
# 3      Think! It's the SCSI card doing the DMA transf...     48
# 4      1) I have an old Jasmine drive which I cannot ...     87
# ...                                                  ...    ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye) DN...     31
# 18842  Not in isolated ground recepticles (usually an...    190
# 18843  I just installed a DX2-66 CPU in a clone mothe...     86
# 18844  Wouldn't this require a hyper-sphere. In 3-spa...     18
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....      8
#
#                                          Name                    CustomName  \
# 0                        0_game_team_games_he             game, team, games
# ...

# %%
result[['Document', 'Representation', 'Probability']]
# Out:
#                                                 Document  \
# 0      I am sure some bashers of Pens fans are pretty...
# 1      My brother is in the market for a high-perform...
# 2      Finally you said what you dream about. Mediter...
# 3      Think! It's the SCSI card doing the DMA transf...
# 4      1) I have an old Jasmine drive which I cannot ...
# ...                                                  ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye) DN...
# 18842  Not in isolated ground recepticles (usually an...
# 18843  I just installed a DX2-66 CPU in a clone mothe...
# 18844  Wouldn't this require a hyper-sphere. In 3-spa...
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....
#
#                                           Representation  Probability
# 0      [game, team, games, he, players, season, hocke...     1.000000
# 1      [card, drivers, diamond, driver, ati, video, c...     1.000000
# ...
